# %%
import sys, os
sys.path += ["../../"]

# %%
# %load_ext autoreload
# %autoreload 1
# %aimport zero_order_gpmpc

# %%
import numpy as np
from scipy.stats import norm
import casadi as cas
from acados_template import AcadosOcp, AcadosSim, AcadosSimSolver, AcadosOcpSolver, AcadosOcpOptions
import matplotlib.pyplot as plt
import torch
import gpytorch

# zoRO imports
import zero_order_gpmpc
from zero_order_gpmpc import ZoroAcados, ZoroAcadosCustomUpdate
from inverted_pendulum_model_acados import export_simplependulum_ode_model, export_ocp_nominal
from utils import base_plot, add_plot_trajectory, EllipsoidTubeData2D

# gpytorch_utils
from gpytorch_utils.gp_hyperparam_training import generate_train_inputs_zoro, generate_train_outputs_at_inputs, train_gp_model
from gpytorch_utils.gp_utils import gp_data_from_model_and_path, gp_derivative_data_from_model_and_path, plot_gp_data, generate_grid_points
from gpytorch_utils.gp_model import MultitaskGPModel, BatchIndependentMultitaskGPModel

# %% [markdown]
# ## Define model parameters
#
# We model the inverted pendulum
#
# $$
# \dot{x} = f(x,u) = \begin{bmatrix} \dot{\theta} \\ \ddot{\theta} \end{bmatrix} = \begin{bmatrix} \dot{\theta} \\ -\sin(\theta) + u \end{bmatrix},
# $$
#
# which is to be controlled from the hanging-down resting position, $(\theta_0, \dot{\theta}_0) = (\pi, 0)$, to the upright position ($(\theta_r, \dot{\theta}_r) = (0,0)$), subject to the constraints that overshoot should be avoided, i.e.,
#
# $$
# \theta_{lb} \leq \theta \leq \theta_{ub}.
# $$
#
# The model setup and controller definition can be found in the functions `export_simplependulum_ode_model()`, `export_ocp_nominal()` in the `inverted_pendulum_model_acados.py` file.

# %%
# build C code again?
build_c_code = True

# %%
# discretization
N = 30
T = 5
dT = T / N

# constraints
x0 = np.array([np.pi, 0])
nx = 2
nu = 1

# %% [markdown]
# ## Set up nominal solver

# %%
ocp_init = export_ocp_nominal(N,T,only_lower_bounds=True)
ocp_init.solver_options.nlp_solver_type = "SQP"

acados_ocp_init_solver = AcadosOcpSolver(ocp_init, json_file="acados_ocp_init_simplependulum_ode.json")
# Out:
# rm -f libacados_ocp_solver_simplependulum_ode.so
# rm -f simplependulum_ode_constraints/simplependulum_ode_constr_h_fun_jac_uxt_zt.o simplependulum_ode_constraints/simplependulum_ode_constr_h_fun.o acados_solver_simplependulum_ode.o
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o simplependulum_ode_constraints/simplependulum_ode_constr_h_fun_jac_uxt_zt.o simplependulum_ode_constraints/simplependulum_ode_constr_h_fun_jac_uxt_zt.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o simplependulum_ode_constraints/simplependulum_ode_constr_h_fun.o simplependulum_ode_constraints/simplependulum_ode_constr_h_fun.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o acados_solver_simplependulum_ode.o acados_solver_simplependulum_ode.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o simplependulum_ode_model/simplependulum_ode_expl_ode_fun.o simplependulum_ode_model/simplependulum_ode_expl_ode_fun.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o simplependulum_ode_model/simplependulum_ode_expl_vde_forw.o simplependulum_ode_model/simplependulum_ode_expl_vde_forw.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o simplependulum_ode_model/simplependulum_ode_expl_vde_adj.o simplependulum_ode_model/simplependulum_ode_expl_vde_adj.c
# cc -shared simplependulum_ode_constraints/simplependulum_ode_constr_h_fun_jac_uxt_zt.o simplependulum_ode_constraints/simplependulum_ode_constr_h_fun.o acados_solver_simplependulum_ode.o simplependulum_ode_model/simplependulum_ode_expl_ode_fun.o simplependulum_ode_model/simplependulum_ode_expl_vde_forw.o simplependulum_ode_model/simplependulum_ode_expl_vde_adj.o -o libacados_ocp_solver_simplependulum_ode.so -L/home/amon/Repositories/zero-order-gp-mpc-github/acados/lib -lacados -lhpipm -lblasfeo -lm \
# -L -l
# acados was compiled without OpenMP.

# %% [markdown]
# ## Open-loop planning with nominal solver

# %%
# get initial values
X_init = np.zeros((N+1, nx))
U_init = np.zeros((N, nu))

# xcurrent = x0
X_init[0,:] = x0

# solve
status_init = acados_ocp_init_solver.solve()

if status_init != 0:
    raise Exception('acados acados_ocp_solver returned status {}. Exiting.'.format(status_init))

# get data
for i in range(N):
    X_init[i,:] = acados_ocp_init_solver.get(i, "x")
    U_init[i,:] = acados_ocp_init_solver.get(i, "u")

X_init[N,:] = acados_ocp_init_solver.get(N, "x")

# %% [markdown]
# ## Simulation results (nominal)

# %%
lb_theta = -ocp_init.constraints.lh[0]
fig, ax = base_plot(lb_theta=lb_theta)

plot_data_nom = EllipsoidTubeData2D(
    center_data = X_init,
    ellipsoid_data = None
)
add_plot_trajectory(ax, plot_data_nom, prob_tighten=None)

# %% [markdown]
# ## Robustify simulation
#
# Now we consider the inverted pendulum subject to process noise, i.e., after discretization,
#
# $$
# x_{k+1} = F(x_k, u_k) + w_k,
# $$
#
# where $w_k \sim \mathcal{N}(0, \Sigma_w)$ denotes process noise and we jhave a potentially nois initial condition $x_0 \sim \mathcal{N}(0, \Sigma_{x0})$ (defined below). Constraints should now be satisfied with satisfaction probability $p_x$, i.e.,
#
# $$
# \mathrm{Pr}(h(x,u) \leq 0) \geq p_x.
# $$
#
# Note that currently zoRO only accepts upper bounds, i.e., we need to reformulate the nominal constraints $\theta \leq \theta_{ub}$, $-\theta \leq -\theta_{lb}$.
# Afterwards, we consider the tightened constraints
#
# $$
# h(x,u) + \alpha \sqrt{C(x,u) P C(x,u)} \leq 0,
# $$
#
# see problem definition https://www.sciencedirect.com/science/article/pii/S0947358023000912, eq. (9).

# %%
# satisfaction probability for chance constraints
prob_x = 0.9
prob_tighten = norm.ppf(prob_x)

# noise
# uncertainty dynamics
sigma_theta = (0.0001/360.) * 2 * np.pi
sigma_omega = (0.0001/360.) * 2 * np.pi
w_theta = 0.03
w_omega = 0.03
Sigma_x0 = np.array([
    [sigma_theta**2,0],
    [0,sigma_omega**2]
])
Sigma_W = np.array([
    [w_theta**2, 0],
    [0, w_omega**2]
])

# %% [markdown]
# ### Nominal OCP with lower bounds

# %%
# without gp model
ocp_zoro_nogp = export_ocp_nominal(N, T, only_lower_bounds=True)

# OCP is discretized inside zoRO solver, so we need to choose DISCRETE integration here
ocp_zoro_nogp.solver_options.integrator_type = "DISCRETE"
ocp_zoro_nogp.solver_options.qp_solver = "PARTIAL_CONDENSING_HPIPM"
ocp_zoro_nogp.solver_options.hessian_approx = "GAUSS_NEWTON"
ocp_zoro_nogp.solver_options.nlp_solver_type = "SQP_RTI"

# %% [markdown]
# ### Nominal model with lower bounds
#
# The tightenings $\sqrt{\ldots}$ can thereby be automatically defined using the `tighten_model_constraints()` function.

# %%
# zoro_solver_nogp = ZoroAcados(ocp_zoro_nogp, sim, prob_x, Sigma_x0, Sigma_W+Sigma_GP_prior)
from zero_order_gpmpc.zoro_acados_utils import generate_h_tightening_funs_SX, only_upper_bounds_expr, tighten_model_constraints

# make constraints one-sided
ocp_model = export_simplependulum_ode_model(only_lower_bounds=True)

# tighten constraints
idh_tight = np.array([0]) # lower constraint on theta (theta >= 0)

ocp_model_tightened, h_jac_x_fun, h_tighten_fun, h_tighten_jac_x_fun, h_tighten_jac_sig_fun = tighten_model_constraints(ocp_model, idh_tight, prob_x)

ocp_zoro_nogp.model = ocp_model_tightened
ocp_zoro_nogp.dims.nh = ocp_model_tightened.con_h_expr.shape[0]
ocp_zoro_nogp.dims.np = ocp_model_tightened.p.shape[0]
ocp_zoro_nogp.parameter_values = np.zeros((ocp_zoro_nogp.dims.np,))
# Out:
# CasADi - 2023-12-17 18:23:55 MESSAGE("calling "gcc -O3 -fPIC -c jit_tmphglhx9.c -o ./tmp_casadi_compiler_shellgz2blx.o"") [.../casadi/solvers/shell_compiler.cpp:232]
# CasADi - 2023-12-17 18:23:55 MESSAGE("calling "gcc ./tmp_casadi_compiler_shellgz2blx.o -o ./tmp_casadi_compiler_shellgz2blx.so -shared"") [.../casadi/solvers/shell_compiler.cpp:251]
# CasADi - 2023-12-17 18:23:55 MESSAGE("calling "gcc -O3 -fPIC -c jit_tmpvaaolm.c -o ./tmp_casadi_compiler_shelln5qhe9.o"") [.../casadi/solvers/shell_compiler.cpp:232]
# CasADi - 2023-12-17 18:23:55 MESSAGE("calling "gcc ./tmp_casadi_compiler_shelln5qhe9.o -o ./tmp_casadi_compiler_shelln5qhe9.so -shared"") [.../casadi/solvers/shell_compiler.cpp:251]
# CasADi - 2023-12-17 18:23:55 MESSAGE("calling "gcc -O3 -fPIC -c jit_tmpvwfaq9.c -o ./tmp_casadi_compiler_shellu33alm.o"") [.../casadi/solvers/shell_compiler.cpp:232]
# CasADi - 2023-12-17 18:23:55 MESSAGE("calling "gcc ./tmp_casadi_compiler_shellu33alm.o -o ./tmp_casadi_compiler_shellu33alm.so -shared"") [.../casadi/solvers/shell_compiler.cpp:251]
# CasADi - 2023-12-17 18:23:55 MESSAGE("calling "gcc -O3 -fPIC -c jit_tmpe5bmk2.c -o ./tmp_casadi_compiler_shellkn66p4.o"") [.../casadi/solvers/shell_compiler.cpp:232]
# CasADi - 2023-12-17 18:23:55 MESSAGE("calling "gcc ./tmp_casadi_compiler_shellkn66p4.o -o ./tmp_casadi_compiler_shellkn66p4.so -shared"") [.../casadi/solvers/shell_compiler.cpp:251]

# %% [markdown]
# ## Simulator object
#
# To automatically discretize the model (and obtain sensitivities of the discrete-time model) within the zero-order implementation, we create the `AcadosSimSolver` object to pass to the solver.

# %%
# integrator for nominal model
sim = AcadosSim()

sim.model = ocp_zoro_nogp.model
sim.parameter_values = ocp_zoro_nogp.parameter_values
sim.solver_options.integrator_type = "ERK"

# set prediction horizon
sim.solver_options.T = dT

# acados_ocp_solver = AcadosOcpSolver(ocp_init, json_file = 'acados_ocp_' + model.name + '.json')
acados_integrator = AcadosSimSolver(sim, json_file = 'acados_sim_' + sim.model.name + '.json')
# Out:
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o acados_sim_solver_simplependulum_ode.o acados_sim_solver_simplependulum_ode.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o simplependulum_ode_model/simplependulum_ode_expl_ode_fun.o simplependulum_ode_model/simplependulum_ode_expl_ode_fun.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o simplependulum_ode_model/simplependulum_ode_expl_vde_forw.o simplependulum_ode_model/simplependulum_ode_expl_vde_forw.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o simplependulum_ode_model/simplependulum_ode_expl_vde_adj.o simplependulum_ode_model/simplependulum_ode_expl_vde_adj.c
# cc -shared acados_sim_solver_simplependulum_ode.o simplependulum_ode_model/simplependulum_ode_expl_ode_fun.o simplependulum_ode_model/simplependulum_ode_expl_vde_forw.o simplependulum_ode_model/simplependulum_ode_expl_vde_adj.o -o libacados_sim_solver_simplependulum_ode.so -L/home/amon/Repositories/zero-order-gp-mpc-github/acados/lib -lacados -lhpipm -lblasfeo -lm
# acados was compiled without OpenMP.

# %% [markdown]
# ## Create zero-order solver (without GP)
#
# Everything comes together in the `ZoroAcados` constructor:
#
# - nominal OCP `ocp_zoro_nogp`,
# - simulator `AcadosSim` object `sim`,
# - satisfaction probability `prob_x`,
# - initial uncertainty `Sigma_x0`,
# - process noise `Sigma_W`,
# - Jacobian of tightened constraints w.r.t. covariances $P$, `h_tighten_jac_sig_fun`

# %%
# solve with zoRO (no GP model, only process noise)
zoro_solver_nogp = ZoroAcados(
    ocp_zoro_nogp, sim, prob_x, Sigma_x0, Sigma_W, 
    h_tightening_jac_sig_fun=h_tighten_jac_sig_fun,
    use_cython=False
)

for i in range(N):
    zoro_solver_nogp.ocp_solver.set(i, "x",X_init[i,:])
    zoro_solver_nogp.ocp_solver.set(i, "u",U_init[i,:])
zoro_solver_nogp.ocp_solver.set(N, "x",X_init[N,:])

zoro_solver_nogp.solve()
X_nogp,U_nogp,P_nogp = zoro_solver_nogp.get_solution()
# Out:
# rm -f libacados_ocp_solver_linear_model_with_params_nx2_nu1_np3.so
# rm -f linear_model_with_params_nx2_nu1_np3_constraints/linear_model_with_params_nx2_nu1_np3_constr_h_fun_jac_uxt_zt.o linear_model_with_params_nx2_nu1_np3_constraints/linear_model_with_params_nx2_nu1_np3_constr_h_fun.o acados_solver_linear_model_with_params_nx2_nu1_np3.o
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o linear_model_with_params_nx2_nu1_np3_constraints/linear_model_with_params_nx2_nu1_np3_constr_h_fun_jac_uxt_zt.o linear_model_with_params_nx2_nu1_np3_constraints/linear_model_with_params_nx2_nu1_np3_constr_h_fun_jac_uxt_zt.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o linear_model_with_params_nx2_nu1_np3_constraints/linear_model_with_params_nx2_nu1_np3_constr_h_fun.o linear_model_with_params_nx2_nu1_np3_constraints/linear_model_with_params_nx2_nu1_np3_constr_h_fun.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o acados_solver_linear_model_with_params_nx2_nu1_np3.o acados_solver_linear_model_with_params_nx2_nu1_np3.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o linear_model_with_params_nx2_nu1_np3_model/linear_model_with_params_nx2_nu1_np3_dyn_disc_phi_fun.o linear_model_with_params_nx2_nu1_np3_model/linear_model_with_params_nx2_nu1_np3_dyn_disc_phi_fun.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o linear_model_with_params_nx2_nu1_np3_model/linear_model_with_params_nx2_nu1_np3_dyn_disc_phi_fun_jac.o linear_model_with_params_nx2_nu1_np3_model/linear_model_with_params_nx2_nu1_np3_dyn_disc_phi_fun_jac.c
# cc -shared linear_model_with_params_nx2_nu1_np3_constraints/linear_model_with_params_nx2_nu1_np3_constr_h_fun_jac_uxt_zt.o linear_model_with_params_nx2_nu1_np3_constraints/linear_model_with_params_nx2_nu1_np3_constr_h_fun.o acados_solver_linear_model_with_params_nx2_nu1_np3.o linear_model_with_params_nx2_nu1_np3_model/linear_model_with_params_nx2_nu1_np3_dyn_disc_phi_fun.o linear_model_with_params_nx2_nu1_np3_model/linear_model_with_params_nx2_nu1_np3_dyn_disc_phi_fun_jac.o -o libacados_ocp_solver_linear_model_with_params_nx2_nu1_np3.so -L/home/amon/Repositories/zero-order-gp-mpc-github/acados/lib -lacados -lhpipm -lblasfeo -lm \
# -L -l
# acados was compiled without OpenMP.
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o acados_sim_solver_simplependulum_ode.o acados_sim_solver_simplependulum_ode.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o simplependulum_ode_model/simplependulum_ode_expl_ode_fun.o simplependulum_ode_model/simplependulum_ode_expl_ode_fun.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o simplependulum_ode_model/simplependulum_ode_expl_vde_forw.o simplependulum_ode_model/simplependulum_ode_expl_vde_forw.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o simplependulum_ode_model/simplependulum_ode_expl_vde_adj.o simplependulum_ode_model/simplependulum_ode_expl_vde_adj.c
# cc -shared acados_sim_solver_simplependulum_ode.o simplependulum_ode_model/simplependulum_ode_expl_ode_fun.o simplependulum_ode_model/simplependulum_ode_expl_vde_forw.o simplependulum_ode_model/simplependulum_ode_expl_vde_adj.o -o libacados_sim_solver_simplependulum_ode.so -L/home/amon/Repositories/zero-order-gp-mpc-github/acados/lib -lacados -lhpipm -lblasfeo -lm
# acados was compiled without OpenMP.
# residuals after  0 SQP_RTI iterations:
#  [2.61799388e+00 3.21205793e-02 4.83118990e-01 1.00000314e-10]
# residuals after  1 SQP_RTI iterations:
#  [8.38749916e-02 4.19534223e-03 1.18992162e-01 1.00000314e-10]
# residuals after  2 SQP_RTI iterations:
#  [9.37869947e-03 9.30640585e-05 3.82469371e-02 1.00000314e-10]
# residuals after  3 SQP_RTI iterations:
#  [2.33955753e-03 9.49541975e-06 2.90535546e-02 1.00000314e-10]
# residuals after  4 SQP_RTI iterations:
#  [4.82024860e-04 1.52568902e-06 2.52456909e-03 1.00000314e-10]
# residuals after  5 SQP_RTI iterations:
#  [1.28396356e-05 8.24297398e-09 1.25390800e-03 1.00000314e-10]
# residuals after  6 SQP_RTI iterations:
#  [1.19849378e-05 3.83184873e-09 2.07504978e-05 1.00000314e-10]
# residuals after  7 SQP_RTI iterations:
#  [1.20355063e-06 1.40631951e-12 2.81161988e-05 1.00000314e-10]
# residuals after  8 SQP_RTI iterations:
#  [2.15258912e-07 2.32397435e-12 3.22504230e-06 1.00000314e-10]
# residuals after  9 SQP_RTI iterations:
#  [4.07048751e-08 2.41334730e-14 2.31507356e-07 1.00000314e-10]

# %% [markdown]
# ### Plot open-loop prediction
#
# Ellipsoids denote the Gaussian confidence intervals, note that one (terminal) ellipsoid "sticks out" since we have omitted the terminal constraint here.

# %%
fig, ax = base_plot(lb_theta=lb_theta)

plot_data_nogp = EllipsoidTubeData2D(
    center_data = X_nogp,
    ellipsoid_data = np.array(P_nogp)
    # ellipsoid_data = None
)
add_plot_trajectory(ax, plot_data_nom, color_fun=plt.cm.Blues, prob_tighten=prob_tighten)
add_plot_trajectory(ax, plot_data_nogp, color_fun=plt.cm.Oranges, prob_tighten=prob_tighten)

# %% [markdown]
# # GP training
#
# We use a model with different parameters to emulate the real-world model and obtain some training data. Also create simulator object for real-world model to evaluate our results later (not used in solver).

# %%
# generate training data for GP with augmented model

# "real model"
model_actual = export_simplependulum_ode_model()
model_actual.f_expl_expr = model_actual.f_expl_expr + cas.vertcat(
    cas.DM(0),
    -0.5*cas.sin((model_actual.x[0])**2)
)
model_actual.f_impl_expr = model_actual.xdot - model_actual.f_expl_expr
model_actual.name = model_actual.name + "_actual"

# acados integrator
sim_actual = AcadosSim()
sim_actual.model = model_actual
sim_actual.solver_options.integrator_type = "ERK"

# set prediction horizon
sim_actual.solver_options.T = dT

# acados_ocp_solver = AcadosOcpSolver(ocp, json_file = 'acados_ocp_' + model.name + '.json')
acados_integrator_actual = AcadosSimSolver(sim_actual, json_file = 'acados_sim_' + model_actual.name + '.json')
# Out:
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o acados_sim_solver_simplependulum_ode_actual.o acados_sim_solver_simplependulum_ode_actual.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o simplependulum_ode_actual_model/simplependulum_ode_actual_expl_ode_fun.o simplependulum_ode_actual_model/simplependulum_ode_actual_expl_ode_fun.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o simplependulum_ode_actual_model/simplependulum_ode_actual_expl_vde_forw.o simplependulum_ode_actual_model/simplependulum_ode_actual_expl_vde_forw.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o simplependulum_ode_actual_model/simplependulum_ode_actual_expl_vde_adj.o simplependulum_ode_actual_model/simplependulum_ode_actual_expl_vde_adj.c
# cc -shared acados_sim_solver_simplependulum_ode_actual.o simplependulum_ode_actual_model/simplependulum_ode_actual_expl_ode_fun.o simplependulum_ode_actual_model/simplependulum_ode_actual_expl_vde_forw.o simplependulum_ode_actual_model/simplependulum_ode_actual_expl_vde_adj.o -o libacados_sim_solver_simplependulum_ode_actual.so -L/home/amon/Repositories/zero-order-gp-mpc-github/acados/lib -lacados -lhpipm -lblasfeo -lm
# acados was compiled without OpenMP.

# %% [markdown]
# ## Generate training data
#
# We generate training data (one-step ahead residuals `y_train` for starting point `x_train`) here by running robustified (cautious) solver without GP.

# %%
random_seed = 123
N_sim_per_x0 = 1
N_x0 = 10
x0_rand_scale = 0.1

x_train, x0_arr = generate_train_inputs_zoro(
    zoro_solver_nogp, 
    x0, 
    N_sim_per_x0, 
    N_x0, 
    random_seed=random_seed, 
    x0_rand_scale=x0_rand_scale
)

y_train = generate_train_outputs_at_inputs(
    x_train, 
    acados_integrator, 
    acados_integrator_actual, 
    Sigma_W
)
# Out:
# residuals after  0 SQP_RTI iterations:
#  [3.16675997e-09 4.44089210e-16 4.27721330e-02 1.00000317e-10]
# residuals after  1 SQP_RTI iterations:
#  [1.81841412e-03 7.39588958e-06 2.66030228e-03 1.00000317e-10]
# residuals after  2 SQP_RTI iterations:
#  [2.85033004e-04 7.59306090e-08 1.40610077e-03 1.00000317e-10]
# residuals after  3 SQP_RTI iterations:
#  [7.24845112e-05 7.52988732e-09 8.56199689e-04 1.00000317e-10]
# residuals after  4 SQP_RTI iterations:
#  [1.48982036e-05 1.23030217e-09 7.01648266e-05 1.00000317e-10]
# residuals after  5 SQP_RTI iterations:
#  [4.64019626e-07 5.34575162e-12 3.86534306e-05 1.00000317e-10]
# residuals after  6 SQP_RTI iterations:
#  [3.81938349e-07 3.57899821e-12 5.65328339e-07 1.00000317e-10]
# residuals after  0 SQP_RTI iterations:
#  [3.61811748e-08 1.11022302e-15 2.02588728e-01 6.54783727e-09]
# residuals after  1 SQP_RTI iterations:
#  [1.88273708e-02 3.21718618e-04 2.90150871e-02 1.00000309e-10]
# residuals after  2 SQP_RTI iterations:
#  [2.57363035e-03 6.44205698e-06 1.14193492e-02 1.00000309e-10]
# residuals after  3 SQP_RTI iterations:
#  [6.04113867e-04 6.27837967e-07 7.24946898e-03 1.00000309e-10]
# residuals after  4 SQP_RTI iterations:
#  [1.27345175e-04 9.25422469e-08 5.91679764e-04 1.00000309e-10]
# residuals after  5 SQP_RTI iterations:
#  [3.45363385e-06 4.19302801e-10 3.12567452e-04 1.00000309e-10]
# residuals after  6 SQP_RTI iterations:
#  [3.11195632e-06 2.37469766e-10 5.02565535e-06 1.00000309e-10]
# residuals after  7 SQP_RTI iterations:
#  [2.96465169e-07 8.22258928e-14 7.07316842e-06 1.00000309e-10]
# residuals after  8 SQP_RTI iterations:
#  [5.37147216e-08 1.45786161e-13 7.80398682e-07 1.00000309e-10]
# residuals after  0 SQP_RTI iterations:
#  [1.01948058e-08 1.45716772e-15 3.49552158e-01 1.00000318e-10]
# residuals after  1 SQP_RTI iterations:
#  [2.93775854e-02 7.22342091e-04 3.56357873e-02 1.00000318e-10]
# residuals after  2 SQP_RTI iterations:
#  [3.95971339e-03 1.42269407e-05 1.72094123e-02 1.00000318e-10]
# residuals after  3 SQP_RTI iterations:
#  [9.59351739e-04 1.36872316e-06 1.20073059e-02 1.00000318e-10]
# residuals after  4 SQP_RTI iterations:
#  [2.05211910e-04 2.44315832e-07 9.33778547e-04 1.00000318e-10]
# residuals after  5 SQP_RTI iterations:
#  [5.09331504e-06 9.12281889e-10 5.40449758e-04 1.00000318e-10]
# residuals after  6 SQP_RTI iterations:
#  [5.15410271e-06 6.98794286e-10 1.09689523e-05 1.00000318e-10]
# residuals after  7 SQP_RTI iterations:
#  [5.25291057e-07 2.92543767e-13 1.22800563e-05 1.00000318e-10]
# residuals after  8 SQP_RTI iterations:
#  [9.39952480e-08 4.41119363e-13 1.44700689e-06 1.00000318e-10]
# residuals after  9 SQP_RTI iterations:
#  [1.77363607e-08 4.87110352e-15 9.68834106e-08 1.00000318e-10]
# residuals after  0 SQP_RTI iterations:
#  [1.48718526e-09 4.44089210e-16 4.74557357e-01 1.29896154e-09]
# residuals after  1 SQP_RTI iterations:
#  [3.65045832e-02 9.81494792e-04 5.17821947e-02 1.00000324e-10]
# residuals after  2 SQP_RTI iterations:
#  [4.81625238e-03 2.34691846e-05 1.81488292e-02 1.00000324e-10]
# residuals after  3 SQP_RTI iterations:
#  [1.41391727e-03 2.33968991e-06 1.70348530e-02 1.00000324e-10]
# residuals after  4 SQP_RTI iterations:
#  [3.09708417e-04 4.86305681e-07 1.40513130e-03 1.00000324e-10]
# residuals after  5 SQP_RTI iterations:
#  [1.36978876e-05 2.03911010e-09 8.39419931e-04 1.00000324e-10]
# residuals after  6 SQP_RTI iterations:
#  [1.05739088e-05 1.59142045e-09 1.93368511e-05 1.00000324e-10]
# residuals after  7 SQP_RTI iterations:
#  [9.19555233e-07 7.79459830e-13 2.34814979e-05 1.00000324e-10]
# residuals after  8 SQP_RTI iterations:
#  [1.90902257e-07 1.41642253e-12 3.11887360e-06 1.00000324e-10]
# residuals after  9 SQP_RTI iterations:
#  [5.01744120e-08 2.08166817e-14 2.93581638e-07 1.00000324e-10]
# residuals after  0 SQP_RTI iterations:
#  [2.43755949e-09 4.44089210e-16 7.86795994e-01 1.00000313e-10]
# residuals after  1 SQP_RTI iterations:
#  [5.48474861e-02 2.29292529e-03 8.58562401e-02 1.00000313e-10]
# residuals after  2 SQP_RTI iterations:
#  [7.71719098e-03 5.63857154e-05 2.83875498e-02 7.16872432e-09]
# residuals after  3 SQP_RTI iterations:
#  [1.67405616e-03 5.10227405e-06 2.16076584e-02 1.00000313e-10]
# residuals after  4 SQP_RTI iterations:
#  [3.74471641e-04 8.18891192e-07 1.57241757e-03 1.00000313e-10]
# residuals after  5 SQP_RTI iterations:
#  [9.10202919e-06 3.00043443e-09 9.26612705e-04 1.00000313e-10]
# residuals after  6 SQP_RTI iterations:
#  [8.95088370e-06 2.07899384e-09 2.24818339e-05 1.00000313e-10]
# residuals after  7 SQP_RTI iterations:
#  [9.38095889e-07 1.08099640e-12 2.04049036e-05 1.00000313e-10]
# residuals after  8 SQP_RTI iterations:
#  [1.56013929e-07 1.22375721e-12 2.47378016e-06 1.00000313e-10]
# residuals after  9 SQP_RTI iterations:
#  [3.03810247e-08 1.45855550e-14 1.60512953e-07 1.00000313e-10]
# residuals after  0 SQP_RTI iterations:
#  [2.37045883e-09 2.22044605e-16 1.87670095e-01 1.00000312e-10]
# residuals after  1 SQP_RTI iterations:
#  [1.02049848e-02 7.65271825e-05 1.30251474e-02 1.00000312e-10]
# residuals after  2 SQP_RTI iterations:
#  [1.26801845e-03 1.52205796e-06 5.13717460e-03 1.00000312e-10]
# residuals after  3 SQP_RTI iterations:
#  [2.95471981e-04 1.43860434e-07 3.74793706e-03 1.00000312e-10]
# residuals after  4 SQP_RTI iterations:
#  [6.34615693e-05 2.44040186e-08 2.91492205e-04 1.00000312e-10]
# residuals after  5 SQP_RTI iterations:
#  [1.47734641e-06 9.81845022e-11 1.64420222e-04 1.00000312e-10]
# residuals after  6 SQP_RTI iterations:
#  [1.57102966e-06 6.50698107e-11 3.43966322e-06 1.00000312e-10]
# residuals after  7 SQP_RTI iterations:
#  [1.60101433e-07 2.85743651e-14 3.68693488e-06 1.00000312e-10]
# residuals after  8 SQP_RTI iterations:
#  [2.81527441e-08 3.97598621e-14 4.35426390e-07 1.00000312e-10]
# residuals after  0 SQP_RTI iterations:
#  [5.35673206e-09 4.71844785e-16 5.47329623e-01 1.75527037e-09]
# residuals after  1 SQP_RTI iterations:
#  [3.37673512e-02 8.49078672e-04 5.02160192e-02 1.00000311e-10]
# residuals after  2 SQP_RTI iterations:
#  [4.24161882e-03 1.70750865e-05 1.75580938e-02 7.06400655e-09]
# residuals after  3 SQP_RTI iterations:
#  [9.40451620e-04 1.62712696e-06 1.11246227e-02 1.00000311e-10]
# residuals after  4 SQP_RTI iterations:
#  [2.18534427e-04 2.24502206e-07 8.65054053e-04 1.03474613e-10]
# residuals after  5 SQP_RTI iterations:
#  [4.45951731e-06 9.74290537e-10 4.76103251e-04 1.38137236e-10]
# residuals after  6 SQP_RTI iterations:
#  [6.32582630e-06 5.45908069e-10 1.42887572e-05 1.38280209e-10]
# residuals after  7 SQP_RTI iterations:
#  [5.68417010e-07 4.05342426e-13 1.19850308e-05 1.37218354e-10]
# residuals after  8 SQP_RTI iterations:
#  [1.09540258e-07 3.87426202e-13 1.58852822e-06 1.37101859e-10]
# residuals after  9 SQP_RTI iterations:
#  [2.71594960e-08 5.93969318e-15 1.56752977e-07 1.37117894e-10]
# residuals after  0 SQP_RTI iterations:
#  [1.25350219e-09 2.22044605e-16 5.98544794e-01 1.00000313e-10]
# residuals after  1 SQP_RTI iterations:
#  [3.85400996e-02 1.13826234e-03 4.58414266e-02 1.00000313e-10]
# residuals after  2 SQP_RTI iterations:
#  [4.78621983e-03 2.16146247e-05 2.10943372e-02 1.00000313e-10]
# residuals after  3 SQP_RTI iterations:
#  [1.17286066e-03 2.12010215e-06 1.45645891e-02 1.00000313e-10]
# residuals after  4 SQP_RTI iterations:
#  [2.46362061e-04 3.63448189e-07 1.17198494e-03 1.00000313e-10]
# residuals after  5 SQP_RTI iterations:
#  [6.56432766e-06 1.50016213e-09 6.49152806e-04 1.00000313e-10]
# residuals after  6 SQP_RTI iterations:
#  [6.21519627e-06 1.01094910e-09 1.18577495e-05 1.00000313e-10]
# residuals after  7 SQP_RTI iterations:
#  [6.17448942e-07 3.83845733e-13 1.47810104e-05 1.00000313e-10]
# residuals after  8 SQP_RTI iterations:
#  [1.12776453e-07 6.37129238e-13 1.70149526e-06 1.00000313e-10]
# residuals after  9 SQP_RTI iterations:
#  [2.11665971e-08 6.73072709e-15 1.22687463e-07 1.00000313e-10]
# residuals after  0 SQP_RTI iterations:
#  [1.66245906e-09 2.22044605e-16 7.49202705e-01 1.39027170e-09]
# residuals after  1 SQP_RTI iterations:
#  [5.06149466e-02 1.99830980e-03 8.08919610e-02 1.00000307e-10]
# residuals after  2 SQP_RTI iterations:
#  [6.23984588e-03 3.97595992e-05 2.82974166e-02 1.00000307e-10]
# residuals after  3 SQP_RTI iterations:
#  [1.34078710e-03 3.86923242e-06 1.58510855e-02 1.81958253e-09]
# residuals after  4 SQP_RTI iterations:
#  [3.13115655e-04 4.67396410e-07 1.25328624e-03 2.44774365e-09]
# residuals after  5 SQP_RTI iterations:
#  [6.51290849e-06 2.16747956e-09 6.57723525e-04 2.81843614e-09]
# residuals after  6 SQP_RTI iterations:
#  [8.92596964e-06 1.05974751e-09 1.88599424e-05 2.83648743e-09]
# residuals after  7 SQP_RTI iterations:
#  [7.77726415e-07 7.22581717e-13 1.63677918e-05 2.82763831e-09]
# residuals after  8 SQP_RTI iterations:
#  [1.55501923e-07 7.29916128e-13 2.11543573e-06 2.82623464e-09]
# residuals after  9 SQP_RTI iterations:
#  [3.69904015e-08 1.07136522e-14 2.18380914e-07 2.82632299e-09]
# residuals after  0 SQP_RTI iterations:
#  [1.73275172e-09 4.44089210e-16 6.59376571e-01 1.00000315e-10]
# residuals after  1 SQP_RTI iterations:
#  [4.84451302e-02 1.89806682e-03 5.50735447e-02 1.00000315e-10]
# residuals after  2 SQP_RTI iterations:
#  [6.07730889e-03 3.43879008e-05 2.77786386e-02 1.00000315e-10]
# residuals after  3 SQP_RTI iterations:
#  [1.49299352e-03 3.36861369e-06 1.82690797e-02 1.00000315e-10]
# residuals after  4 SQP_RTI iterations:
#  [3.12897776e-04 5.69496653e-07 1.47722275e-03 1.00000315e-10]
# residuals after  5 SQP_RTI iterations:
#  [8.47397912e-06 2.32774092e-09 8.17847601e-04 1.00000315e-10]
# residuals after  6 SQP_RTI iterations:
#  [7.90368450e-06 1.60478686e-09 1.46009670e-05 1.00000315e-10]
# residuals after  7 SQP_RTI iterations:
#  [7.81977552e-07 5.98604499e-13 1.86633644e-05 1.00000315e-10]
# residuals after  8 SQP_RTI iterations:
#  [1.42410814e-07 1.01574305e-12 2.13624478e-06 1.00000315e-10]
# residuals after  9 SQP_RTI iterations:
#  [2.68315974e-08 1.06165077e-14 1.57063632e-07 1.00000315e-10]

# %% [markdown]
# ## Hyper-parameter training for GP model
#
# Optimize hyper-parameters of GP model (kernel function parameters, ...)

# %%
x_train_tensor = torch.Tensor(x_train)
y_train_tensor = torch.Tensor(y_train)
nout = y_train.shape[1]

likelihood = gpytorch.likelihoods.MultitaskGaussianLikelihood(
    num_tasks = nout
)
gp_model = BatchIndependentMultitaskGPModel(x_train_tensor, y_train_tensor, likelihood, nout)

# %%
training_iterations = 200
rng_seed = 456

gp_model, likelihood = train_gp_model(gp_model, torch_seed=rng_seed, training_iterations=training_iterations)

# EVAL MODE
gp_model.eval()
likelihood.eval()
# Out:
# Iter 1/200 - Loss: 1.462
# Iter 2/200 - Loss: 1.424
# Iter 3/200 - Loss: 1.386
# Iter 4/200 - Loss: 1.347
# Iter 5/200 - Loss: 1.307
# Iter 6/200 - Loss: 1.267
# Iter 7/200 - Loss: 1.225
# Iter 8/200 - Loss: 1.184
# Iter 9/200 - Loss: 1.141
# Iter 10/200 - Loss: 1.098
# Iter 11/200 - Loss: 1.054
# Iter 12/200 - Loss: 1.010
# Iter 13/200 - Loss: 0.964
# Iter 14/200 - Loss: 0.919
# Iter 15/200 - Loss: 0.873
# Iter 16/200 - Loss: 0.826
# Iter 17/200 - Loss: 0.779
# Iter 18/200 - Loss: 0.731
# Iter 19/200 - Loss: 0.683
# Iter 20/200 - Loss: 0.635
# Iter 21/200 - Loss: 0.586
# Iter 22/200 - Loss: 0.536
# Iter 23/200 - Loss: 0.487
# Iter 24/200 - Loss: 0.437
# Iter 25/200 - Loss: 0.387
# Iter 26/200 - Loss: 0.336
# Iter 27/200 - Loss: 0.286
# Iter 28/200 - Loss: 0.235
# Iter 29/200 - Loss: 0.184
# Iter 30/200 - Loss: 0.133
# Iter 31/200 - Loss: 0.082
# Iter 32/200 - Loss: 0.030
# Iter 33/200 - Loss: -0.021
# Iter 34/200 - Loss: -0.073
# Iter 35/200 - Loss: -0.124
# Iter 36/200 - Loss: -0.176
# Iter 37/200 - Loss: -0.227
# Iter 38/200 - Loss: -0.278
# Iter 39/200 - Loss: -0.330
# Iter 40/200 - Loss: -0.381
# Iter 41/200 - Loss: -0.432
# Iter 42/200 - Loss: -0.483
# Iter 43/200 - Loss: -0.534
# Iter 44/200 - Loss: -0.584
# Iter 45/200 - Loss: -0.635
# Iter 46/200 - Loss: -0.685
# Iter 47/200 - Loss: -0.734
# Iter 48/200 - Loss: -0.784
# Iter 49/200 - Loss: -0.833
# Iter 50/200 - Loss: -0.881
# Iter 51/200 - Loss: -0.929
# Iter 52/200 - Loss: -0.977
# Iter 53/200 - Loss: -1.023
# Iter 54/200 - Loss: -1.070
# Iter 55/200 - Loss: -1.115
# Iter 56/200 - Loss: -1.160
# Iter 57/200 - Loss: -1.204
# Iter 58/200 - Loss: -1.247
# Iter 59/200 - Loss: -1.289
# Iter 60/200 - Loss: -1.330
# Iter 61/200 - Loss: -1.370
# Iter 62/200 - Loss: -1.409
# Iter 63/200 - Loss: -1.446
# Iter 64/200 - Loss: -1.483
# Iter 65/200 - Loss: -1.518
# Iter 66/200 - Loss: -1.552
# Iter 67/200 - Loss: -1.584
# Iter 68/200 - Loss: -1.616
# Iter 69/200 - Loss: -1.646
# Iter 70/200 - Loss: -1.676
# Iter 71/200 - Loss: -1.704
# Iter 72/200 - Loss: -1.732
# Iter 73/200 - Loss: -1.760
# Iter 74/200 - Loss: -1.786
# Iter 75/200 - Loss: -1.812
# Iter 76/200 - Loss: -1.837
# Iter 77/200 - Loss: -1.860
# Iter 78/200 - Loss: -1.882
# Iter 79/200 - Loss: -1.901
# Iter 80/200 - Loss: -1.918
# Iter 81/200 - Loss: -1.932
# Iter 82/200 - Loss: -1.945
# Iter 83/200 - Loss: -1.956
# Iter 84/200 - Loss: -1.965
# Iter 85/200 - Loss: -1.974
# Iter 86/200 - Loss: -1.981
# Iter 87/200 - Loss: -1.988
# Iter 88/200 - Loss: -1.995
# Iter 89/200 - Loss: -2.001
# Iter 90/200 - Loss: -2.006
# Iter 91/200 - Loss: -2.011
# Iter 92/200 - Loss: -2.016
# Iter 93/200 - Loss: -2.019
# Iter 94/200 - Loss: -2.023
# Iter 95/200 - Loss: -2.025
# Iter 96/200 - Loss: -2.028
# Iter 97/200 - Loss: -2.029
# Iter 98/200 - Loss: -2.030
# Iter 99/200 - Loss: -2.031
# Iter 100/200 - Loss: -2.032
# Iter 101/200 - Loss: -2.033
# Iter 102/200 - Loss: -2.033
# Iter 103/200 - Loss: -2.033
# Iter 104/200 - Loss: -2.034
# Iter 105/200 - Loss: -2.034
# Iter 106/200 - Loss: -2.035
# Iter 107/200 - Loss: -2.035
# Iter 108/200 - Loss: -2.036
# Iter 109/200 - Loss: -2.036
# Iter 110/200 - Loss: -2.036
# Iter 111/200 - Loss: -2.036
# Iter 112/200 - Loss: -2.036
# Iter 113/200 - Loss: -2.036
# Iter 114/200 - Loss: -2.036
# Iter 115/200 - Loss: -2.036
# Iter 116/200 - Loss: -2.036
# Iter 117/200 - Loss: -2.036
# Iter 118/200 - Loss: -2.036
# Iter 119/200 - Loss: -2.037
# Iter 120/200 - Loss: -2.037
# Iter 121/200 - Loss: -2.037
# Iter 122/200 - Loss: -2.037
# Iter 123/200 - Loss: -2.037
# Iter 124/200 - Loss: -2.037
# Iter 125/200 - Loss: -2.037
# Iter 126/200 - Loss: -2.037
# Iter 127/200 - Loss: -2.037
# Iter 128/200 - Loss: -2.037
# Iter 129/200 - Loss: -2.037
# Iter 130/200 - Loss: -2.038
# Iter 131/200 - Loss: -2.038
# Iter 132/200 - Loss: -2.038
# Iter 133/200 - Loss: -2.038
# Iter 134/200 - Loss: -2.038
# Iter 135/200 - Loss: -2.038
# Iter 136/200 - Loss: -2.038
# Iter 137/200 - Loss: -2.038
# Iter 138/200 - Loss: -2.038
# Iter 139/200 - Loss: -2.038
# Iter 140/200 - Loss: -2.038
# Iter 141/200 - Loss: -2.038
# Iter 142/200 - Loss: -2.038
# Iter 143/200 - Loss: -2.038
# Iter 144/200 - Loss: -2.038
# Iter 145/200 - Loss: -2.039
# Iter 146/200 - Loss: -2.039
# Iter 147/200 - Loss: -2.039
# Iter 148/200 - Loss: -2.039
# Iter 149/200 - Loss: -2.039
# Iter 150/200 - Loss: -2.039
# Iter 151/200 - Loss: -2.039
# Iter 152/200 - Loss: -2.039
# Iter 153/200 - Loss: -2.039
# Iter 154/200 - Loss: -2.039
# Iter 155/200 - Loss: -2.039
# Iter 156/200 - Loss: -2.039
# Iter 157/200 - Loss: -2.039
# Iter 158/200 - Loss: -2.039
# Iter 159/200 - Loss: -2.039
# Iter 160/200 - Loss: -2.039
# Iter 161/200 - Loss: -2.039
# Iter 162/200 - Loss: -2.039
# Iter 163/200 - Loss: -2.039
# Iter 164/200 - Loss: -2.039
# Iter 165/200 - Loss: -2.039
# Iter 166/200 - Loss: -2.039
# Iter 167/200 - Loss: -2.039
# Iter 168/200 - Loss: -2.039
# Iter 169/200 - Loss: -2.039
# Iter 170/200 - Loss: -2.039
# Iter 171/200 - Loss: -2.039
# Iter 172/200 - Loss: -2.039
# Iter 173/200 - Loss: -2.039
# Iter 174/200 - Loss: -2.039
# Iter 175/200 - Loss: -2.039
# Iter 176/200 - Loss: -2.039
# Iter 177/200 - Loss: -2.039
# Iter 178/200 - Loss: -2.039
# Iter 179/200 - Loss: -2.039
# Iter 180/200 - Loss: -2.039
# Iter 181/200 - Loss: -2.039
# Iter 182/200 - Loss: -2.039
# Iter 183/200 - Loss: -2.039
# Iter 184/200 - Loss: -2.039
# Iter 185/200 - Loss: -2.039
# Iter 186/200 - Loss: -2.039
# Iter 187/200 - Loss: -2.039
# Iter 188/200 - Loss: -2.039
# Iter 189/200 - Loss: -2.039
# Iter 190/200 - Loss: -2.039
# Iter 191/200 - Loss: -2.039
# Iter 192/200 - Loss: -2.039
# Iter 193/200 - Loss: -2.039
# Iter 194/200 - Loss: -2.039
# Iter 195/200 - Loss: -2.039
# Iter 196/200 - Loss: -2.039
# Iter 197/200 - Loss: -2.039
# Iter 198/200 - Loss: -2.039
# Iter 199/200 - Loss: -2.039
# Iter 200/200 - Loss: -2.039
# MultitaskGaussianLikelihood(
#   (raw_task_noises_constraint): GreaterThan(1.000E-04)
#   (raw_noise_constraint): GreaterThan(1.000E-04)
# )

# %% [markdown]
# ## Plot GP predictions
#
# We plot GP predictions along the predicted trajectory of the robustified solver by projecting the multivariate plot down to a line.

# %%
num_samples = 5
use_likelihood = False

num_points_between_samples = 30
t_lin = np.linspace(0,1,num_points_between_samples,endpoint=False)

x_plot_waypts = np.hstack((
    X_nogp[1:,:],
    U_nogp
)) 
x_plot = []
for i in range(x_plot_waypts.shape[0]-1):
    x_plot += [x_plot_waypts[i,:] + (x_plot_waypts[i+1,:] - x_plot_waypts[i,:]) * t for t in t_lin]
x_plot = np.vstack(x_plot)

gp_data = gp_data_from_model_and_path(gp_model, likelihood, x_plot, num_samples=num_samples, use_likelihood=use_likelihood)
plot_gp_data([gp_data], marker_size_lim=[1, 15])
# Out:
# (<Figure size 800x600 with 2 Axes>,
#  array([<Axes: title={'center': 'Observed Values (Likelihood), output 0'}>,
#         <Axes: title={'center': 'Observed Values (Likelihood), output 1'}>],
#        dtype=object))

# %% [markdown]
# We can also plot the derivative of the GP. Note that the projected Jacobian is not smooth since our path is not smooth either (jump projection direction = jump in Jacobian); however, the actual Jacobian should be smooth here (squared exponential kernel).

# %%
gp_derivative_data = gp_derivative_data_from_model_and_path(gp_model, likelihood, x_plot, num_samples=0)
plot_gp_data([gp_derivative_data], marker_size_lim=[5, 20], plot_train_data=False)
# Out:
# (<Figure size 800x600 with 2 Axes>,
#  array([<Axes: title={'center': 'Observed Values (Likelihood), output 0'}>,
#         <Axes: title={'center': 'Observed Values (Likelihood), output 1'}>],
#        dtype=object))

# %% [markdown]
# Compare with plotting along a slice of the dimension. Since we generated training data along the path of the robustified controller, the GP looks pretty untrained along a slice of the coordinates.

# %%
# plot along axis
x_dim_lims = np.array([
    [0, np.pi],
    [-2, 1],
    [-2, 2]
    ])
x_dim_slice = np.array([
    1 * np.pi,
    0,
    0
])
x_dim_plot = 2
x_grid = generate_grid_points(x_dim_lims, x_dim_slice, x_dim_plot, num_points=800)

gp_grid_data = gp_data_from_model_and_path(gp_model, likelihood, x_grid, num_samples=num_samples, use_likelihood=use_likelihood)
fig, ax = plot_gp_data([gp_grid_data], marker_size_lim=[5, 50])

y_lim_0 = ax[0].get_ylim()
y_lim_1 = ax[1].get_ylim()

# %% [markdown]
# Jacobian... not much going on away from the data points (this is good!)

# %%
gp_derivative_grid_data = gp_derivative_data_from_model_and_path(gp_model, likelihood, x_grid, num_samples=0)
fig, ax = plot_gp_data([gp_derivative_grid_data], marker_size_lim=[5, 50], plot_train_data=False)

ax[0].set_ylim(*y_lim_0)
ax[1].set_ylim(*y_lim_1)
plt.draw()

# %% [markdown]
# # Zero-Order GP-MPC
#
# We can add the GP model to the solver by simply adding it as an argument to the `ZoroAcados` function. Therefore we copy (important!) the robustified controller and then instantiate another solver object.

# %%
from copy import deepcopy
ocp_zoro = deepcopy(ocp_zoro_nogp)

zoro_solver = ZoroAcados(
    ocp_zoro, sim, prob_x, Sigma_x0, Sigma_W, 
    h_tightening_jac_sig_fun=h_tighten_jac_sig_fun, 
    gp_model=gp_model,
    use_cython=False
)

for i in range(N):
    zoro_solver.ocp_solver.set(i, "x",X_init[i,:])
    zoro_solver.ocp_solver.set(i, "u",U_init[i,:])
zoro_solver.ocp_solver.set(N, "x",X_init[N,:])

zoro_solver.solve()
X,U,P = zoro_solver.get_solution()
# Out:
# rm -f libacados_ocp_solver_linear_model_with_params_nx2_nu1_np3.so
# rm -f linear_model_with_params_nx2_nu1_np3_constraints/linear_model_with_params_nx2_nu1_np3_constr_h_fun_jac_uxt_zt.o linear_model_with_params_nx2_nu1_np3_constraints/linear_model_with_params_nx2_nu1_np3_constr_h_fun.o acados_solver_linear_model_with_params_nx2_nu1_np3.o
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o linear_model_with_params_nx2_nu1_np3_constraints/linear_model_with_params_nx2_nu1_np3_constr_h_fun_jac_uxt_zt.o linear_model_with_params_nx2_nu1_np3_constraints/linear_model_with_params_nx2_nu1_np3_constr_h_fun_jac_uxt_zt.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o linear_model_with_params_nx2_nu1_np3_constraints/linear_model_with_params_nx2_nu1_np3_constr_h_fun.o linear_model_with_params_nx2_nu1_np3_constraints/linear_model_with_params_nx2_nu1_np3_constr_h_fun.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o acados_solver_linear_model_with_params_nx2_nu1_np3.o acados_solver_linear_model_with_params_nx2_nu1_np3.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o linear_model_with_params_nx2_nu1_np3_model/linear_model_with_params_nx2_nu1_np3_dyn_disc_phi_fun.o linear_model_with_params_nx2_nu1_np3_model/linear_model_with_params_nx2_nu1_np3_dyn_disc_phi_fun.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o linear_model_with_params_nx2_nu1_np3_model/linear_model_with_params_nx2_nu1_np3_dyn_disc_phi_fun_jac.o linear_model_with_params_nx2_nu1_np3_model/linear_model_with_params_nx2_nu1_np3_dyn_disc_phi_fun_jac.c
# cc -shared linear_model_with_params_nx2_nu1_np3_constraints/linear_model_with_params_nx2_nu1_np3_constr_h_fun_jac_uxt_zt.o linear_model_with_params_nx2_nu1_np3_constraints/linear_model_with_params_nx2_nu1_np3_constr_h_fun.o acados_solver_linear_model_with_params_nx2_nu1_np3.o linear_model_with_params_nx2_nu1_np3_model/linear_model_with_params_nx2_nu1_np3_dyn_disc_phi_fun.o linear_model_with_params_nx2_nu1_np3_model/linear_model_with_params_nx2_nu1_np3_dyn_disc_phi_fun_jac.o -o libacados_ocp_solver_linear_model_with_params_nx2_nu1_np3.so -L/home/amon/Repositories/zero-order-gp-mpc-github/acados/lib -lacados -lhpipm -lblasfeo -lm \
# -L -l
# acados was compiled without OpenMP.
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o acados_sim_solver_simplependulum_ode.o acados_sim_solver_simplependulum_ode.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o simplependulum_ode_model/simplependulum_ode_expl_ode_fun.o simplependulum_ode_model/simplependulum_ode_expl_ode_fun.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o simplependulum_ode_model/simplependulum_ode_expl_vde_forw.o simplependulum_ode_model/simplependulum_ode_expl_vde_forw.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o simplependulum_ode_model/simplependulum_ode_expl_vde_adj.o simplependulum_ode_model/simplependulum_ode_expl_vde_adj.c
# cc -shared acados_sim_solver_simplependulum_ode.o simplependulum_ode_model/simplependulum_ode_expl_ode_fun.o simplependulum_ode_model/simplependulum_ode_expl_vde_forw.o simplependulum_ode_model/simplependulum_ode_expl_vde_adj.o -o libacados_sim_solver_simplependulum_ode.so -L/home/amon/Repositories/zero-order-gp-mpc-github/acados/lib -lacados -lhpipm -lblasfeo -lm
# acados was compiled without OpenMP.
# residuals after  0 SQP_RTI iterations:
#  [2.61799388e+00 9.91521379e-02 8.88444220e-01 1.00000314e-10]
# residuals after  1 SQP_RTI iterations:
#  [6.27257467e-01 3.23778953e-02 4.56189613e-01 1.00000314e-10]
# residuals after  2 SQP_RTI iterations:
#  [1.33142591e-01 3.44587763e-03 4.82693729e-01 1.00000314e-10]
# residuals after  3 SQP_RTI iterations:
#  [2.11738379e-02 2.46010632e-03 3.38968642e-01 1.17698241e-09]
# residuals after  4 SQP_RTI iterations:
#  [2.14939007e-02 7.90418026e-04 9.20923752e-02 1.00000314e-10]
# residuals after  5 SQP_RTI iterations:
#  [1.26141676e-02 6.16380731e-05 2.46590479e-02 1.00000314e-10]
# residuals after  6 SQP_RTI iterations:
#  [4.89084206e-03 1.82077262e-05 2.57861618e-02 1.00000314e-10]
# residuals after  7 SQP_RTI iterations:
#  [4.04631716e-03 1.27416603e-05 1.07275946e-02 1.00000314e-10]
# residuals after  8 SQP_RTI iterations:
#  [2.10037423e-03 3.73030513e-06 6.57084024e-03 1.00000314e-10]
# residuals after  9 SQP_RTI iterations:
#  [1.30070435e-03 1.32330206e-06 4.53895946e-03 1.00000314e-10]
# residuals after  10 SQP_RTI iterations:
#  [9.03974276e-04 1.16003765e-06 2.63749619e-03 1.00000314e-10]
# residuals after  11 SQP_RTI iterations:
#  [5.20510838e-04 9.34704211e-07 1.65157997e-03 1.00000314e-10]
# residuals after  12 SQP_RTI iterations:
#  [3.24144692e-04 1.26051472e-06 1.07432480e-03 1.00000314e-10]
# residuals after  13 SQP_RTI iterations:
#  [2.07390499e-04 1.41169801e-06 6.77287268e-04 1.00000314e-10]
# residuals after  14 SQP_RTI iterations:
#  [1.30869613e-04 7.73851356e-07 4.43421178e-04 1.00000314e-10]
# residuals after  15 SQP_RTI iterations:
#  [8.82263191e-05 7.21897064e-07 2.74862090e-04 1.00000314e-10]
# residuals after  16 SQP_RTI iterations:
#  [5.35840760e-05 1.49087213e-06 1.64643421e-04 1.00000314e-10]
# residuals after  17 SQP_RTI iterations:
#  [3.18905993e-05 9.05627609e-07 9.09934484e-05 1.00000314e-10]
# residuals after  18 SQP_RTI iterations:
#  [1.97832294e-05 1.74260511e-06 3.86631972e-05 1.00000314e-10]
# residuals after  19 SQP_RTI iterations:
#  [1.55891177e-05 1.44168735e-06 1.97997325e-05 1.00000314e-10]
# residuals after  20 SQP_RTI iterations:
#  [1.50445412e-05 1.06938086e-06 1.46796022e-05 1.00000314e-10]
# residuals after  21 SQP_RTI iterations:
#  [5.93582841e-06 9.67471056e-07 9.74065938e-06 1.00000314e-10]
# residuals after  22 SQP_RTI iterations:
#  [9.06015286e-06 1.31701272e-06 9.82396721e-06 1.00000314e-10]
# residuals after  23 SQP_RTI iterations:
#  [1.04099681e-05 1.67479549e-06 1.19173616e-05 1.00000314e-10]
# residuals after  24 SQP_RTI iterations:
#  [7.55497224e-06 1.59280092e-06 1.41696545e-05 1.00000314e-10]
# residuals after  25 SQP_RTI iterations:
#  [6.97098624e-06 9.81817291e-07 2.11844483e-05 1.00000314e-10]
# residuals after  26 SQP_RTI iterations:
#  [8.59678047e-06 1.06246812e-06 2.88999350e-05 1.00000314e-10]
# residuals after  27 SQP_RTI iterations:
#  [7.59931741e-06 8.58585217e-07 3.31263405e-05 1.00000314e-10]
# residuals after  28 SQP_RTI iterations:
#  [6.48925664e-06 1.20392379e-06 3.40187358e-05 1.00000314e-10]
# residuals after  29 SQP_RTI iterations:
#  [1.10118963e-05 2.41751202e-06 2.41369364e-05 1.00000314e-10]

# %% [markdown]
# ### Custom Update version

# %%
# # we use both-sided bounds again, specify which bound to be tightened using according index
# ocp_cupdate = export_ocp_nominal(N,T,only_lower_bounds=False)
# we use one-sided bounds since we just want to tighten upper bound
ocp_cupdate = export_ocp_nominal(N,T,only_lower_bounds=True,model_name='simplependulum_ode_cupdate')

# tighten constraints
idh_tight = np.array([0]) # lower on theta (theta >= 0)

# integrator for nominal model
sim_cupdate = AcadosSim()

sim_cupdate.model = ocp_cupdate.model
sim_cupdate.parameter_values = ocp_cupdate.parameter_values
sim_cupdate.solver_options.integrator_type = "ERK"

# set prediction horizon
sim_cupdate.solver_options.T = dT

# acados_ocp_solver = AcadosOcpSolver(ocp_init, json_file = 'acados_ocp_' + model.name + '.json')
acados_integrator_cupdate = AcadosSimSolver(sim_cupdate, json_file = 'acados_sim_' + sim_cupdate.model.name + '_cupdate.json')
# Out:
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o acados_sim_solver_simplependulum_ode_cupdate.o acados_sim_solver_simplependulum_ode_cupdate.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o simplependulum_ode_cupdate_model/simplependulum_ode_cupdate_expl_ode_fun.o simplependulum_ode_cupdate_model/simplependulum_ode_cupdate_expl_ode_fun.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o simplependulum_ode_cupdate_model/simplependulum_ode_cupdate_expl_vde_forw.o simplependulum_ode_cupdate_model/simplependulum_ode_cupdate_expl_vde_forw.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o simplependulum_ode_cupdate_model/simplependulum_ode_cupdate_expl_vde_adj.o simplependulum_ode_cupdate_model/simplependulum_ode_cupdate_expl_vde_adj.c
# cc -shared acados_sim_solver_simplependulum_ode_cupdate.o simplependulum_ode_cupdate_model/simplependulum_ode_cupdate_expl_ode_fun.o simplependulum_ode_cupdate_model/simplependulum_ode_cupdate_expl_vde_forw.o simplependulum_ode_cupdate_model/simplependulum_ode_cupdate_expl_vde_adj.o -o libacados_sim_solver_simplependulum_ode_cupdate.so -L/home/amon/Repositories/zero-order-gp-mpc-github/acados/lib -lacados -lhpipm -lblasfeo -lm
# acados was compiled without OpenMP.

# %%
# %aimport zero_order_gpmpc
# import importlib
# importlib.reload(zero_order_gpmpc)
# from zero_order_gpmpc import ZoroAcadosCustomUpdate

zoro_solver_cupdate = zero_order_gpmpc.ZoroAcadosCustomUpdate(
    ocp_cupdate, sim_cupdate, prob_x, Sigma_x0, Sigma_W, 
    h_tightening_idx=idh_tight, 
    gp_model=gp_model,
    use_cython=True, #TODO: fix cython issue
    path_json_ocp="zoro_ocp_solver_config_cupdate.json",
    path_json_sim="zoro_sim_solver_config_cupdate.json",
)   

for i in range(N):
    zoro_solver_cupdate.ocp_solver.set(i, "x",X_init[i,:])
    zoro_solver_cupdate.ocp_solver.set(i, "u",U_init[i,:])
zoro_solver_cupdate.ocp_solver.set(N, "x",X_init[N,:])

zoro_solver_cupdate.solve()
X_cup,U_cup,P_cup = zoro_solver_cupdate.get_solution()
# Out:
# make: *** No rule to make target 'clean_all'.  Stop.
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o linear_model_with_params_nx2_nu1_np0_constraints/linear_model_with_params_nx2_nu1_np0_constr_h_fun_jac_uxt_zt.o linear_model_with_params_nx2_nu1_np0_constraints/linear_model_with_params_nx2_nu1_np0_constr_h_fun_jac_uxt_zt.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o linear_model_with_params_nx2_nu1_np0_constraints/linear_model_with_params_nx2_nu1_np0_constr_h_fun.o linear_model_with_params_nx2_nu1_np0_constraints/linear_model_with_params_nx2_nu1_np0_constr_h_fun.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o custom_update_function_gpzoro.o custom_update_function_gpzoro.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o acados_solver_linear_model_with_params_nx2_nu1_np0.o acados_solver_linear_model_with_params_nx2_nu1_np0.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o linear_model_with_params_nx2_nu1_np0_model/linear_model_with_params_nx2_nu1_np0_dyn_disc_phi_fun.o linear_model_with_params_nx2_nu1_np0_model/linear_model_with_params_nx2_nu1_np0_dyn_disc_phi_fun.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o linear_model_with_params_nx2_nu1_np0_model/linear_model_with_params_nx2_nu1_np0_dyn_disc_phi_fun_jac.o linear_model_with_params_nx2_nu1_np0_model/linear_model_with_params_nx2_nu1_np0_dyn_disc_phi_fun_jac.c
# cc -shared linear_model_with_params_nx2_nu1_np0_constraints/linear_model_with_params_nx2_nu1_np0_constr_h_fun_jac_uxt_zt.o linear_model_with_params_nx2_nu1_np0_constraints/linear_model_with_params_nx2_nu1_np0_constr_h_fun.o custom_update_function_gpzoro.o acados_solver_linear_model_with_params_nx2_nu1_np0.o linear_model_with_params_nx2_nu1_np0_model/linear_model_with_params_nx2_nu1_np0_dyn_disc_phi_fun.o linear_model_with_params_nx2_nu1_np0_model/linear_model_with_params_nx2_nu1_np0_dyn_disc_phi_fun_jac.o -o libacados_ocp_solver_linear_model_with_params_nx2_nu1_np0.so -L/home/amon/Repositories/zero-order-gp-mpc-github/acados/lib -lacados -lhpipm -lblasfeo -lm \
# -L -l
# cython \
# -o acados_ocp_solver_pyx.c \
# -I /home/amon/Repositories/zero-order-gp-mpc-github/acados/include/../interfaces/acados_template/acados_template \
# /home/amon/Repositories/zero-order-gp-mpc-github/acados/include/../interfaces/acados_template/acados_template/acados_ocp_solver_pyx.pyx \
# -I /home/amon/Repositories/zero-order-gp-mpc-github/examples/inverted_pendulum/c_generated_code \
#
# cc  -c -O2 \
# -fPIC \
# -o acados_ocp_solver_pyx.o \
# -I /home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include/ \
# -I /home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include/ \
# -I /home/amon/Repositories/zero-order-gp-mpc-github/acados/include \
# -I /home/amon/.local/share/virtualenvs/zero-order-gp-mpc-github-Y-8U9LdN/lib/python3.9/site-packages/numpy/core/include \
# -I /home/amon/.pyenv/versions/3.9.13/include/python3.9 \
# acados_ocp_solver_pyx.c \
# In file included from /home/amon/.local/share/virtualenvs/zero-order-gp-mpc-github-Y-8U9LdN/lib/python3.9/site-packages/numpy/core/include/numpy/ndarraytypes.h:1929,
#                  from /home/amon/.local/share/virtualenvs/zero-order-gp-mpc-github-Y-8U9LdN/lib/python3.9/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /home/amon/.local/share/virtualenvs/zero-order-gp-mpc-github-Y-8U9LdN/lib/python3.9/site-packages/numpy/core/include/numpy/arrayobject.h:5,
#                  from acados_ocp_solver_pyx.c:1195:
# /home/amon/.local/share/virtualenvs/zero-order-gp-mpc-github-Y-8U9LdN/lib/python3.9/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# cc  -shared \
# -o acados_ocp_solver_pyx.so \
# -Wl,-rpath=/home/amon/Repositories/zero-order-gp-mpc-github/acados/lib \
# acados_ocp_solver_pyx.o \
# /home/amon/Repositories/zero-order-gp-mpc-github/examples/inverted_pendulum/c_generated_code/libacados_ocp_solver_linear_model_with_params_nx2_nu1_np0.so \
# -L/home/amon/Repositories/zero-order-gp-mpc-github/acados/lib -lacados -lhpipm -lblasfeo -lm
# rm -f libacados_sim_solver_simplependulum_ode_cupdate.so
# rm -f acados_sim_solver_simplependulum_ode_cupdate.o
# rm -f acados_sim_solver_pyx.so
# rm -f acados_sim_solver_pyx.o
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o acados_sim_solver_simplependulum_ode_cupdate.o acados_sim_solver_simplependulum_ode_cupdate.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o simplependulum_ode_cupdate_model/simplependulum_ode_cupdate_expl_ode_fun.o simplependulum_ode_cupdate_model/simplependulum_ode_cupdate_expl_ode_fun.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o simplependulum_ode_cupdate_model/simplependulum_ode_cupdate_expl_vde_forw.o simplependulum_ode_cupdate_model/simplependulum_ode_cupdate_expl_vde_forw.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o simplependulum_ode_cupdate_model/simplependulum_ode_cupdate_expl_vde_adj.o simplependulum_ode_cupdate_model/simplependulum_ode_cupdate_expl_vde_adj.c
# cc -shared acados_sim_solver_simplependulum_ode_cupdate.o simplependulum_ode_cupdate_model/simplependulum_ode_cupdate_expl_ode_fun.o simplependulum_ode_cupdate_model/simplependulum_ode_cupdate_expl_vde_forw.o simplependulum_ode_cupdate_model/simplependulum_ode_cupdate_expl_vde_adj.o -o libacados_sim_solver_simplependulum_ode_cupdate.so -L/home/amon/Repositories/zero-order-gp-mpc-github/acados/lib -lacados -lhpipm -lblasfeo -lm
# cython \
# -o acados_sim_solver_pyx.c \
# -I /home/amon/Repositories/zero-order-gp-mpc-github/acados/include/../interfaces/acados_template/acados_template \
# /home/amon/Repositories/zero-order-gp-mpc-github/acados/include/../interfaces/acados_template/acados_template/acados_sim_solver_pyx.pyx \
# -I /home/amon/Repositories/zero-order-gp-mpc-github/examples/inverted_pendulum/c_generated_code \
#
# cc  -c -O2 \
# -fPIC \
# -o acados_sim_solver_pyx.o \
# -I /home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include/ \
# -I /home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include/ \
# -I /home/amon/Repositories/zero-order-gp-mpc-github/acados/include \
# -I /home/amon/.local/share/virtualenvs/zero-order-gp-mpc-github-Y-8U9LdN/lib/python3.9/site-packages/numpy/core/include \
# -I /home/amon/.pyenv/versions/3.9.13/include/python3.9 \
# acados_sim_solver_pyx.c \
# In file included from /home/amon/.local/share/virtualenvs/zero-order-gp-mpc-github-Y-8U9LdN/lib/python3.9/site-packages/numpy/core/include/numpy/ndarraytypes.h:1929,
#                  from /home/amon/.local/share/virtualenvs/zero-order-gp-mpc-github-Y-8U9LdN/lib/python3.9/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /home/amon/.local/share/virtualenvs/zero-order-gp-mpc-github-Y-8U9LdN/lib/python3.9/site-packages/numpy/core/include/numpy/arrayobject.h:5,
#                  from acados_sim_solver_pyx.c:1195:
# /home/amon/.local/share/virtualenvs/zero-order-gp-mpc-github-Y-8U9LdN/lib/python3.9/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# cc  -shared \
# -o acados_sim_solver_pyx.so \
# -Wl,-rpath=/home/amon/Repositories/zero-order-gp-mpc-github/acados/lib \
# acados_sim_solver_pyx.o \
# /home/amon/Repositories/zero-order-gp-mpc-github/examples/inverted_pendulum/c_generated_code/libacados_sim_solver_simplependulum_ode_cupdate.so \
# -L/home/amon/Repositories/zero-order-gp-mpc-github/acados/lib -lacados -lhpipm -lblasfeo -lm
# residuals after  0 SQP_RTI iterations:
#  [2.61799388e+00 9.91521379e-02 8.88444220e-01 1.00000314e-10]
# residuals after  1 SQP_RTI iterations:
#  [6.27257467e-01 3.23778953e-02 4.07786804e-01 1.00000314e-10]
# residuals after  2 SQP_RTI iterations:
#  [6.82192476e-02 4.15115338e-03 1.75204830e-01 1.00000314e-10]
# residuals after  3 SQP_RTI iterations:
#  [3.55053523e-02 1.16848322e-03 1.01111053e-01 1.00000314e-10]
# residuals after  4 SQP_RTI iterations:
#  [2.01671643e-02 3.04433223e-04 6.02396571e-02 1.00000314e-10]
# residuals after  5 SQP_RTI iterations:
#  [1.20645474e-02 1.14330554e-04 3.69214344e-02 1.00000314e-10]
# residuals after  6 SQP_RTI iterations:
#  [7.31676785e-03 3.94484626e-05 2.26917197e-02 1.00000314e-10]
# residuals after  7 SQP_RTI iterations:
#  [4.50258077e-03 1.53402570e-05 1.41142643e-02 1.00000314e-10]
# residuals after  8 SQP_RTI iterations:
#  [2.78897311e-03 5.22353240e-06 8.77210620e-03 1.00000314e-10]
# residuals after  9 SQP_RTI iterations:
#  [1.73354709e-03 2.58205540e-06 5.48311523e-03 1.00000314e-10]
# residuals after  10 SQP_RTI iterations:
#  [1.08130141e-03 1.45832095e-06 3.43803407e-03 1.00000314e-10]
# residuals after  11 SQP_RTI iterations:
#  [6.80071870e-04 9.42803722e-07 2.16134637e-03 1.00000314e-10]
# residuals after  12 SQP_RTI iterations:
#  [4.27709673e-04 1.20747887e-06 1.35546472e-03 1.00000314e-10]
# residuals after  13 SQP_RTI iterations:
#  [2.67094497e-04 1.44498149e-06 8.52894648e-04 1.00000314e-10]
# residuals after  14 SQP_RTI iterations:
#  [1.68306908e-04 9.06270893e-07 5.37812628e-04 1.00000314e-10]
# residuals after  15 SQP_RTI iterations:
#  [1.05675788e-04 8.79071960e-07 3.40262012e-04 1.00000314e-10]
# residuals after  16 SQP_RTI iterations:
#  [6.55456740e-05 1.16411738e-06 2.12683539e-04 1.00000314e-10]
# residuals after  17 SQP_RTI iterations:
#  [4.06199082e-05 1.33500632e-06 1.36599566e-04 1.00000314e-10]
# residuals after  18 SQP_RTI iterations:
#  [2.67971204e-05 9.67961911e-07 8.97006031e-05 1.00000314e-10]
# residuals after  19 SQP_RTI iterations:
#  [1.83779622e-05 1.11967276e-06 5.92324341e-05 1.00000314e-10]
# residuals after  20 SQP_RTI iterations:
#  [1.86074653e-05 7.97212124e-07 3.46316012e-05 1.00000314e-10]
# residuals after  21 SQP_RTI iterations:
#  [1.46717917e-05 8.11367445e-07 2.26183456e-05 1.00000314e-10]
# residuals after  22 SQP_RTI iterations:
#  [9.86758456e-06 1.25030890e-06 2.45305065e-05 1.00000314e-10]
# residuals after  23 SQP_RTI iterations:
#  [6.16980947e-06 1.55914544e-06 2.25275247e-05 1.00000314e-10]
# residuals after  24 SQP_RTI iterations:
#  [9.30640305e-06 7.56233201e-07 2.35371557e-05 1.00000314e-10]
# residuals after  25 SQP_RTI iterations:
#  [9.96961796e-06 7.54884609e-07 3.19529757e-05 1.00000314e-10]
# residuals after  26 SQP_RTI iterations:
#  [1.08190622e-05 1.19165469e-06 3.51062631e-05 1.00000314e-10]
# residuals after  27 SQP_RTI iterations:
#  [2.00275932e-05 9.79751348e-07 3.97422127e-05 1.00000314e-10]
# residuals after  28 SQP_RTI iterations:
#  [1.65912578e-05 9.54114694e-07 4.46308083e-05 1.00000314e-10]
# residuals after  29 SQP_RTI iterations:
#  [8.82323623e-06 1.04680657e-06 4.74715246e-05 1.00000314e-10]

# %% [markdown]
# ### Custom update (with GP) vs. GP -> the same!

# %%
fig, ax = base_plot(lb_theta=lb_theta)

plot_data_gp = EllipsoidTubeData2D(
    center_data = X,
    ellipsoid_data = np.array(P)
    # ellipsoid_data = None
)

plot_data_gp_cupdate = EllipsoidTubeData2D(
    center_data = X_cup,
    ellipsoid_data = np.array(P_cup)
    # ellipsoid_data = None
)
add_plot_trajectory(ax, plot_data_gp_cupdate, color_fun=plt.cm.Greens)
add_plot_trajectory(ax, plot_data_gp, color_fun=plt.cm.Reds)

# %% [markdown]
# ## Trained GP vs. no GP
#
# Plotting trained GP against no-GP, we see that the GP-MPC controller still has higher uncertainties than the robustified one. This is because the GP covariance, albeit being small where data points are, is *added* to the process noise, i.e., we make the controller even more cautious.

# %%
fig, ax = base_plot(lb_theta=lb_theta)

plot_data_gp = EllipsoidTubeData2D(
    center_data = X,
    ellipsoid_data = np.array(P)
    # ellipsoid_data = None
)
add_plot_trajectory(ax, plot_data_nogp, color_fun=plt.cm.Oranges)
add_plot_trajectory(ax, plot_data_gp, color_fun=plt.cm.Reds)

# %% [markdown]
# We can get a more insightful comparison by comparing the *conditioned* GP (i.e., with optimized hyper-parameters and data), to the *unconditioned* GP (i.e., with the same, optimized hyper-parameters and no data).
#
# As you can see, the hyper-parameter optimization also provides us with an estimate of the measurement noise for the data points, which corersponds to added process noise in our model (epistemic uncertainty).

# %%
ocp_zoro_gpprior = deepcopy(ocp_zoro_nogp)

gp_model.eval()
y_test = torch.Tensor(np.array([[1,1,1]]))
Sigma_GP_prior = gp_model.covar_module(y_test).numpy()

Sigma_GP_prior = np.diag(Sigma_GP_prior.flatten())
Sigma_GP_prior
# Out:
# array([[9.397028e-06, 0.000000e+00],
#        [0.000000e+00, 3.572325e-03]], dtype=float32)

# %%
Sigma_W
# Out:
# array([[0.0009, 0.    ],
#        [0.    , 0.0009]])

# %% [markdown]
# Especially in the velocity component, this really makes a difference!

# %%
Sigma_W+Sigma_GP_prior
# Out:
# array([[0.0009094 , 0.        ],
#        [0.        , 0.00447232]])

# %% [markdown]
# Now we solve again with *unconditioned* GP and compare...

# %%
# zoro_solver_gpprior = ZoroAcados(ocp_zoro_gpprior, sim, prob_x, Sigma_x0, Sigma_W+Sigma_GP_prior)
zoro_solver_gpprior = ZoroAcados(
    ocp_zoro_gpprior, sim, prob_x, Sigma_x0, Sigma_W+Sigma_GP_prior, 
    h_tightening_jac_sig_fun=h_tighten_jac_sig_fun,
    use_cython=False
)

for i in range(N):
    zoro_solver_gpprior.ocp_solver.set(i, "x",X_init[i,:])
    zoro_solver_gpprior.ocp_solver.set(i, "u",U_init[i,:])
zoro_solver_gpprior.ocp_solver.set(N, "x",X_init[N,:])
# Out:
# rm -f libacados_ocp_solver_linear_model_with_params_nx2_nu1_np3.so
# rm -f linear_model_with_params_nx2_nu1_np3_constraints/linear_model_with_params_nx2_nu1_np3_constr_h_fun_jac_uxt_zt.o linear_model_with_params_nx2_nu1_np3_constraints/linear_model_with_params_nx2_nu1_np3_constr_h_fun.o acados_solver_linear_model_with_params_nx2_nu1_np3.o
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o linear_model_with_params_nx2_nu1_np3_constraints/linear_model_with_params_nx2_nu1_np3_constr_h_fun_jac_uxt_zt.o linear_model_with_params_nx2_nu1_np3_constraints/linear_model_with_params_nx2_nu1_np3_constr_h_fun_jac_uxt_zt.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o linear_model_with_params_nx2_nu1_np3_constraints/linear_model_with_params_nx2_nu1_np3_constr_h_fun.o linear_model_with_params_nx2_nu1_np3_constraints/linear_model_with_params_nx2_nu1_np3_constr_h_fun.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o acados_solver_linear_model_with_params_nx2_nu1_np3.o acados_solver_linear_model_with_params_nx2_nu1_np3.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o linear_model_with_params_nx2_nu1_np3_model/linear_model_with_params_nx2_nu1_np3_dyn_disc_phi_fun.o linear_model_with_params_nx2_nu1_np3_model/linear_model_with_params_nx2_nu1_np3_dyn_disc_phi_fun.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o linear_model_with_params_nx2_nu1_np3_model/linear_model_with_params_nx2_nu1_np3_dyn_disc_phi_fun_jac.o linear_model_with_params_nx2_nu1_np3_model/linear_model_with_params_nx2_nu1_np3_dyn_disc_phi_fun_jac.c
# cc -shared linear_model_with_params_nx2_nu1_np3_constraints/linear_model_with_params_nx2_nu1_np3_constr_h_fun_jac_uxt_zt.o linear_model_with_params_nx2_nu1_np3_constraints/linear_model_with_params_nx2_nu1_np3_constr_h_fun.o acados_solver_linear_model_with_params_nx2_nu1_np3.o linear_model_with_params_nx2_nu1_np3_model/linear_model_with_params_nx2_nu1_np3_dyn_disc_phi_fun.o linear_model_with_params_nx2_nu1_np3_model/linear_model_with_params_nx2_nu1_np3_dyn_disc_phi_fun_jac.o -o libacados_ocp_solver_linear_model_with_params_nx2_nu1_np3.so -L/home/amon/Repositories/zero-order-gp-mpc-github/acados/lib -lacados -lhpipm -lblasfeo -lm \
# -L -l
# acados was compiled without OpenMP.
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o acados_sim_solver_simplependulum_ode.o acados_sim_solver_simplependulum_ode.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o simplependulum_ode_model/simplependulum_ode_expl_ode_fun.o simplependulum_ode_model/simplependulum_ode_expl_ode_fun.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o simplependulum_ode_model/simplependulum_ode_expl_vde_forw.o simplependulum_ode_model/simplependulum_ode_expl_vde_forw.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o simplependulum_ode_model/simplependulum_ode_expl_vde_adj.o simplependulum_ode_model/simplependulum_ode_expl_vde_adj.c
# cc -shared acados_sim_solver_simplependulum_ode.o simplependulum_ode_model/simplependulum_ode_expl_ode_fun.o simplependulum_ode_model/simplependulum_ode_expl_vde_forw.o simplependulum_ode_model/simplependulum_ode_expl_vde_adj.o -o libacados_sim_solver_simplependulum_ode.so -L/home/amon/Repositories/zero-order-gp-mpc-github/acados/lib -lacados -lhpipm -lblasfeo -lm
# acados was compiled without OpenMP.

# %%
zoro_solver_gpprior.solve()

X_gpprior,U_gpprior,P_gpprior = zoro_solver_gpprior.get_solution()
# Out:
# residuals after  0 SQP_RTI iterations:
#  [2.61799388e+00 3.21205793e-02 7.93518067e-01 6.53985770e-09]
# residuals after  1 SQP_RTI iterations:
#  [1.31459872e-01 7.57864857e-03 4.28670232e-01 4.95308544e-10]
# residuals after  2 SQP_RTI iterations:
#  [2.24728803e-02 1.02640244e-03 8.61559680e-02 8.05326857e-09]
# residuals after  3 SQP_RTI iterations:
#  [6.14354919e-03 5.05595680e-05 1.67126855e-01 1.00000314e-10]
# residuals after  4 SQP_RTI iterations:
#  [2.29797615e-03 5.03190524e-05 2.93105387e-03 5.77343807e-09]
# residuals after  5 SQP_RTI iterations:
#  [5.27825787e-05 3.12786571e-08 1.28614021e-02 1.00000314e-10]
# residuals after  6 SQP_RTI iterations:
#  [1.34265668e-04 2.02826650e-07 1.53371417e-03 1.00000314e-10]
# residuals after  7 SQP_RTI iterations:
#  [1.96443032e-05 3.78551437e-09 5.08577222e-04 1.00000314e-10]
# residuals after  8 SQP_RTI iterations:
#  [5.76045980e-06 3.74201448e-10 1.54574770e-04 1.00000314e-10]
# residuals after  9 SQP_RTI iterations:
#  [1.78633393e-06 3.59801355e-11 2.04414624e-06 1.00000314e-10]
# residuals after  10 SQP_RTI iterations:
#  [1.03386603e-07 1.21014310e-14 8.13694618e-06 1.00000314e-10]
# residuals after  11 SQP_RTI iterations:
#  [9.53412105e-08 1.02556852e-13 1.23941290e-06 1.00000314e-10]
# residuals after  12 SQP_RTI iterations:
#  [1.53575512e-08 2.02615702e-15 2.04889809e-07 1.00000314e-10]

# %% [markdown]
# ## Zero-Order GP-MPC with unconditioned GP vs. conditioned GP
#
# Now we see that the training indeed paid off, and reduced uncertainty where we obtained data, i.e., we can go closer to the boundary while still being cautious.

# %%
fig, ax = base_plot(lb_theta=lb_theta)

plot_data_gpprior = EllipsoidTubeData2D(
    center_data = X_gpprior,
    ellipsoid_data = np.array(P_gpprior)
    # ellipsoid_data = None
)
add_plot_trajectory(ax, plot_data_gp, color_fun=plt.cm.Reds)
add_plot_trajectory(ax, plot_data_gpprior, color_fun=plt.cm.Blues)
